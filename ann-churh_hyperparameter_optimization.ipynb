# %% [markdown]
# # Machine Learning vs Deep Learning - Same Use Case

# %% [markdown]
# ## Prepare Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('../data-sets/Churn_Modelling.csv')

# %%
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values

# %%
X
# Out:
# array([[619, 'France', 'Female', ..., 1, 1, 101348.88],
#        [608, 'Spain', 'Female', ..., 0, 1, 112542.58],
#        [502, 'France', 'Female', ..., 1, 0, 113931.57],
#        ...,
#        [709, 'France', 'Female', ..., 0, 1, 42085.58],
#        [772, 'Germany', 'Male', ..., 1, 0, 92888.52],
#        [792, 'France', 'Female', ..., 1, 0, 38190.78]], dtype=object)

# %%
# Encoding categorical data

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
X[:,1] = labelencoder_X_1.fit_transform(X[:,1])

labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:,2])

# %%
X # After encoding
# Out:
# array([[619, 0, 0, ..., 1, 1, 101348.88],
#        [608, 2, 0, ..., 0, 1, 112542.58],
#        [502, 0, 0, ..., 1, 0, 113931.57],
#        ...,
#        [709, 0, 0, ..., 0, 1, 42085.58],
#        [772, 1, 1, ..., 1, 0, 92888.52],
#        [792, 0, 0, ..., 1, 0, 38190.78]], dtype=object)

# %%
# Train-Test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Classic Machine Learning

# %%
# Decision Tree classifier
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
pred = clf.predict(X_test)


# Confusion Matrix, Accuracy Score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

cm = confusion_matrix(y_test, pred)
score = accuracy_score(y_test, pred)
print('cm:', cm, '    accuracy_scpre:', score*100)
# Out:
# cm: [[1373  222]
#  [ 179  226]]     accuracy_scpre: 79.95

# %%
# Random Forest classifier
from sklearn.ensemble import RandomForestClassifier

clf2 = RandomForestClassifier(n_estimators=100)
clf2.fit(X_train, y_train)
pred2 = clf2.predict(X_test)

# %%
# Confusion Matrix / Accuracy Score
cm2 = confusion_matrix(y_test, pred2)
score2 = accuracy_score(y_test, pred2)
print('cm:', cm2, '    accuracy_scpre:', score2*100)
# Out:
# cm: [[1529   66]
#  [ 209  196]]     accuracy_scpre: 86.25

# %%
# %pip install tensorflow-macos

# %% [markdown]
# ## Artificial Neural Network

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 2.16.2
# 3.13.2

# %%
# # Initialising the ANN
# classifier = Sequential()
# #units: It's an art, comes by experience, input+output/2
# #initializer: how your weights are updated
# #relu activation function
# #input_dim: input shape (shape of the data, how many features do we have in the data)
# # Adding the input layer and the first hidden layer
# classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))

# # Adding the second hidden layer
# classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# # Adding the third  hidden layer
# classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# # Adding the output layer
# classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

classifier = Sequential([
    Input(shape=(10,)),  # 10 features
    Dense(6, activation='relu'),
    Dense(6, activation='relu'),
    Dense(6, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %%
len(X_train)
# Out:
# 8000

# %%
import numpy as np
y = np.asarray(y_train).reshape(-1)
baseline = max(y.mean(), 1 - y.mean())
print("Majority-class baseline accuracy:", baseline)
# Out:
# Majority-class baseline accuracy: 0.796

# %%
# Compiling the ANN 
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
y_train[0]

# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 200)
# Out:
# Epoch 1/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 615us/step - accuracy: 0.7936 - loss: 0.4974
# Epoch 2/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - accuracy: 0.7960 - loss: 0.4393
# Epoch 3/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - accuracy: 0.8035 - loss: 0.4244
# Epoch 4/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - accuracy: 0.8269 - loss: 0.4156
# Epoch 5/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - accuracy: 0.8305 - loss: 0.4062
# Epoch 6/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - accuracy: 0.8339 - loss: 0.3975
# Epoch 7/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.8346 - loss: 0.3892
# Epoch 8/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - accuracy: 0.8354 - loss: 0.3841
# Epoch 9/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.8372 - loss: 0.3808
# Epoch 10/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - accuracy: 0.8405 - loss: 0.3765
# Epoch 11/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - accuracy: 0.8435 - loss: 0.3740
# Epoch 12/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - accuracy: 0.8454 - loss: 0.3703
# Epoch 13/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - accuracy: 0.8482 - loss: 0.3680
# Epoch 14/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step - accuracy: 0.8506 - loss: 0.3651
# Epoch 15/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step - accuracy: 0.8506 - loss: 0.3626
# Epoch 16/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - accuracy: 0.8509 - loss: 0.3597
# Epoch 17/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.8524 - loss: 0.3575
# Epoch 18/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - accuracy: 0.
200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - accuracy: 0.8640 - loss: 0.3330
# Epoch 147/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - accuracy: 0.8615 - loss: 0.3336
# Epoch 148/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.8614 - loss: 0.3344
# Epoch 149/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - accuracy: 0.8635 - loss: 0.3350
# Epoch 150/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step - accuracy: 0.8634 - loss: 0.3339
# Epoch 151/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - accuracy: 0.8631 - loss: 0.3340
# Epoch 152/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - accuracy: 0.8643 - loss: 0.3339
# Epoch 153/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - accuracy: 0.8629 - loss: 0.3346
# Epoch 154/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - accuracy: 0.8629 - loss: 0.3341
# Epoch 155/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - accuracy: 0.8616 - loss: 0.3337
# Epoch 156/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - accuracy: 0.8612 - loss: 0.3341
# Epoch 157/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - accuracy: 0.8600 - loss: 0.3337
# Epoch 158/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - accuracy: 0.8625 - loss: 0.3342
# Epoch 159/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - accuracy: 0.8634 - loss: 0.3331
# Epoch 160/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - accuracy: 0.8641 - loss: 0.3343
# Epoch 161/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - accuracy: 0.8601 - loss: 0.3345
# Epoch 162/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - accuracy: 0.8610 - loss: 0.3339
# Epoch 163/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - accuracy: 0.8634 - loss: 0.3331
# Epoch 164/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 0.8615 - loss: 0.3333
# Epoch 165/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 0.8618 - loss: 0.3330
# Epoch 166/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - accuracy: 0.8639 - loss: 0.3332
# Epoch 167/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - accuracy: 0.8604 - loss: 0.3340
# Epoch 168/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - accuracy: 0.8627 - loss: 0.3327
# Epoch 169/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - accuracy: 0.8631 - loss: 0.3333
# Epoch 170/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - accuracy: 0.8616 - loss: 0.3348
# Epoch 171/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - accuracy: 0.8619 - loss: 0.3330
# Epoch 172/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - accuracy: 0.8633 - loss: 0.3322
# Epoch 173/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - accuracy: 0.8630 - loss: 0.3324
# Epoch 174/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - accuracy: 0.8612 - loss: 0.3336
# Epoch 175/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - accuracy: 0.8629 - loss: 0.3332
# Epoch 176/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - accuracy: 0.8639 - loss: 0.3339
# Epoch 177/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - accuracy: 0.8622 - loss: 0.3331
# Epoch 178/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - accuracy: 0.8624 - loss: 0.3334
# Epoch 179/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - accuracy: 0.8619 - loss: 0.3337
# Epoch 180/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.8626 - loss: 0.3325
# Epoch 181/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - accuracy: 0.8622 - loss: 0.3326
# Epoch 182/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - accuracy: 0.8644 - loss: 0.3330
# Epoch 183/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - accuracy: 0.8618 - loss: 0.3319
# Epoch 184/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - accuracy: 0.8629 - loss: 0.3322
# Epoch 185/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - accuracy: 0.8630 - loss: 0.3319
# Epoch 186/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - accuracy: 0.8633 - loss: 0.3326
# Epoch 187/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - accuracy: 0.8619 - loss: 0.3328
# Epoch 188/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 0.8645 - loss: 0.3320
# Epoch 189/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - accuracy: 0.8637 - loss: 0.3324
# Epoch 190/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - accuracy: 0.8639 - loss: 0.3328
# Epoch 191/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - accuracy: 0.8650 - loss: 0.3313
# Epoch 192/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - accuracy: 0.8645 - loss: 0.3323
# Epoch 193/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - accuracy: 0.8641 - loss: 0.3317
# Epoch 194/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - accuracy: 0.8636 - loss: 0.3311
# Epoch 195/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - accuracy: 0.8624 - loss: 0.3320
# Epoch 196/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 0.8626 - loss: 0.3314
# Epoch 197/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - accuracy: 0.8631 - loss: 0.3320
# Epoch 198/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.8644 - loss: 0.3315
# Epoch 199/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 0.8636 - loss: 0.3314
# Epoch 200/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - accuracy: 0.8646 - loss: 0.3314

# %%
# Part 3 - Making predictions and evaluating the model
# Predicting the Test set results
y_pred_ann = classifier.predict(X_test)
y_pred_ann = (y_pred_ann > 0.5)

cm3 = confusion_matrix(y_test, y_pred_ann)
print(cm3)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step
# [[1499   96]
#  [ 191  214]]

# %%
# Making the Confusion Matrix
from sklearn.metrics import accuracy_score

score3 = accuracy_score(y_test,y_pred_ann)
print(score3*100)
# Out:
# 85.65

# %% [markdown]
# ## Hyperparamter Optimization

# %% [markdown]
# Run smaller tests first because these can be very expensive computationally.

# %% [markdown]
# ### Grid Search

# %%
# Predict a single observation

"""Predict if the customer with the following informations will leave the bank:
Geography: France
Credit Score: 600
Gender: Male
Age: 40
Tenure: 3
Balance: 60000
Number of Products: 2
Has Credit Card: Yes
Is Active Member: Yes
Estimated Salary: 50000"""

new_prediction = classifier.predict(sc.transform(np.array([[600, 0, 1, 40, 3, 60000, 2, 1, 1, 50000]])))
new_prediction = (new_prediction > 0.5)
new_prediction

# Making the Confusion Matrix
#from sklearn.metrics import confusion_matrixx
#cm = confusion_matrix(y_test, y_pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# array([[False]])

# %%
import time
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout

def build_classifier():
    model = Sequential([
        Input(shape=(10,)),
        Dense(12, activation="relu"),
        Dropout(0.25),

        Dense(12, activation="relu"),
        Dropout(0.25),

        Dense(6, activation="relu"),

        Dense(1, activation="sigmoid")
    ])
    model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
    return model

classifier = KerasClassifier(model=build_classifier, verbose=0)

parameters = {
    "batch_size": [10, 20, 100],
    "epochs": [5, 6, 10, 20],
    "loss": ['binary_crossentropy', 'categorical_crossentropy'],
    "optimizer": ['adam', 'rmsprop']

}

grid_search = GridSearchCV(
    estimator=classifier,
    param_grid=parameters,
    scoring="accuracy",
    cv=5,
    n_jobs=1
)

#start timer
start_time = time.time()

grid_search.fit(X_train, y_train)

#End timer
end_time = time.time()
elapsed_time = end_time - start_time

print(grid_search.best_params_)
print(grid_search.best_score_)
print(f"\nExecution time: {elapsed_time:.2f} seconds ({elapsed_time/60:.2f} minutes)")

# %%
# %pip install scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /Users/stevesimonson/development/tutorials/PythonforDS/.venv/lib/python3.12/site-packages (from scikeras) (3.13.2)
# Requirement already satisfied: scikit-learn>=1.4.2 in /Users/stevesimonson/development/tutorials/PythonforDS/.venv/lib/python3.12/site-packages (from scikeras) (1.8.0)
# Requirement already satisfied: absl-py in /Users/stevesimonson/development/tutorials/PythonforDS/.venv/lib/python3.12/site-packages (from keras>=3.2.0->scikeras) (2.4.0)
# Requirement already satisfied: numpy in /Users/stevesimonson/development/tutorials/PythonforDS/.venv/lib/python3.12/site-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /Users/stevesimonson/development/tutorials/PythonforDS/.venv/lib/python3.12/site-packages (from keras>=3.2.0->scikeras) (14.3.3)
# Requirement already satisfied: namex in /Users/stevesimonson/development/tutorials/PythonforDS/.venv/lib/python3.12/site-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: h5py in /Users/stevesimonson/development/tutorials/PythonforDS/.venv/lib/python3.12/site-packages (from keras>=3.2.0->scikeras) (3.15.1)
# Requirement already satisfied: optree in /Users/stevesimonson/development/tutorials/PythonforDS/.venv/lib/python3.12/site-packages (from keras>=3.2.0->scikeras) (0.19.0)
# Requirement already satisfied: ml-dtypes in /Users/stevesimonson/development/tutorials/PythonforDS/.venv/lib/python3.12/site-packages (from keras>=3.2.0->scikeras) (0.3.2)
# Requirement already satisfied: packaging in /Users/stevesimonson/development/tutorials/PythonforDS/.venv/lib/python3.12/site-packages (from keras>=3.2.0->scikeras) (25.0)
# Requirement already satisfied: scipy>=1.10.0 in /Users/stevesimonson/development/tutorials/PythonforDS/.venv/lib/python3.12/site-packages (from scikit-learn>=1.4.2->scikeras) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /Users/stevesimonson/development/tutorials/PythonforDS/.venv/lib/python3.12/site-packages (from scikit-learn>=1.4.2->scikeras) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/stevesimonson/development/tutorials/PythonforDS/.venv/lib/python3.12/site-packages (from scikit-learn>=1.4.2->scikeras) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/stevesimonson/development/tutorials/PythonforDS/.venv/lib/python3.12/site-packages (from optree->keras>=3.2.0->scikeras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/stevesimonson/development/tutorials/PythonforDS/.venv/lib/python3.12/site-packages (from rich->keras>=3.2.0->scikeras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/stevesimonson/development/tutorials/PythonforDS/.venv/lib/python3.12/site-packages (from rich->keras>=3.2.0->scikeras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/stevesimonson/development/tutorials/PythonforDS/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Improving the performance of ANN

# %% [markdown]
# 1. Increase the number of hidden layers
# 2. Increase number or epochs
# 3. FIne-tuning the parameters - optimizers, batch_size, epochs
# 4. Dropout regularization: Dropout(0.25)
#
# Overfitting problem: training accuracy increases, but test accuracy is low
