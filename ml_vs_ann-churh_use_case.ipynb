# %% [markdown]
# # Machine Learning vs Deep Learning - Same Use Case

# %% [markdown]
# ## Prepare Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('../data-sets/Churn_Modelling.csv')

# %%
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values

# %%
X
# Out:
# array([[619, 'France', 'Female', ..., 1, 1, 101348.88],
#        [608, 'Spain', 'Female', ..., 0, 1, 112542.58],
#        [502, 'France', 'Female', ..., 1, 0, 113931.57],
#        ...,
#        [709, 'France', 'Female', ..., 0, 1, 42085.58],
#        [772, 'Germany', 'Male', ..., 1, 0, 92888.52],
#        [792, 'France', 'Female', ..., 1, 0, 38190.78]], dtype=object)

# %%
# Encoding categorical data

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
X[:,1] = labelencoder_X_1.fit_transform(X[:,1])

labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:,2])

# %%
X # After encoding
# Out:
# array([[619, 0, 0, ..., 1, 1, 101348.88],
#        [608, 2, 0, ..., 0, 1, 112542.58],
#        [502, 0, 0, ..., 1, 0, 113931.57],
#        ...,
#        [709, 0, 0, ..., 0, 1, 42085.58],
#        [772, 1, 1, ..., 1, 0, 92888.52],
#        [792, 0, 0, ..., 1, 0, 38190.78]], dtype=object)

# %%
# Train-Test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Classic Machine Learning

# %%
# Decision Tree classifier
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
pred = clf.predict(X_test)


# Confusion Matrix, Accuracy Score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

cm = confusion_matrix(y_test, pred)
score = accuracy_score(y_test, pred)
print('cm:', cm, '    accuracy_scpre:', score*100)
# Out:
# cm: [[1364  231]
#  [ 187  218]]     accuracy_scpre: 79.10000000000001

# %%
# Random Forest classifier
from sklearn.ensemble import RandomForestClassifier

clf2 = RandomForestClassifier(n_estimators=100)
clf2.fit(X_train, y_train)
pred2 = clf2.predict(X_test)

# %%
# Confusion Matrix / Accuracy Score
cm2 = confusion_matrix(y_test, pred2)
score2 = accuracy_score(y_test, pred2)
print('cm:', cm2, '    accuracy_scpre:', score2*100)
# Out:
# cm: [[1517   78]
#  [ 199  206]]     accuracy_scpre: 86.15

# %%
# %pip install tensorflow-macos

# %% [markdown]
# ## Artificial Neural Network

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 2.16.2
# 3.13.2

# %%
# # Initialising the ANN
# classifier = Sequential()
# #units: It's an art, comes by experience, input+output/2
# #initializer: how your weights are updated
# #relu activation function
# #input_dim: input shape (shape of the data, how many features do we have in the data)
# # Adding the input layer and the first hidden layer
# classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))

# # Adding the second hidden layer
# classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# # Adding the third  hidden layer
# classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# # Adding the output layer
# classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

classifier = Sequential([
    Input(shape=(10,)),  # 10 features
    Dense(6, activation='relu'),
    Dense(6, activation='relu'),
    Dense(6, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %%
len(X_train)
# Out:
# 8000

# %%
import numpy as np
y = np.asarray(y_train).reshape(-1)
baseline = max(y.mean(), 1 - y.mean())
print("Majority-class baseline accuracy:", baseline)
# Out:
# Majority-class baseline accuracy: 0.796

# %%
# Compiling the ANN 
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
y_train[0]

# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 200)
# Out:
# Epoch 1/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 557us/step - accuracy: 0.7427 - loss: 0.5336
# Epoch 2/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - accuracy: 0.8255 - loss: 0.4197
# Epoch 3/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.8418 - loss: 0.3880
# Epoch 4/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - accuracy: 0.8500 - loss: 0.3693
# Epoch 5/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - accuracy: 0.8525 - loss: 0.3617
# Epoch 6/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - accuracy: 0.8558 - loss: 0.3577
# Epoch 7/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - accuracy: 0.8560 - loss: 0.3554
# Epoch 8/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - accuracy: 0.8529 - loss: 0.3538
# Epoch 9/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - accuracy: 0.8555 - loss: 0.3524
# Epoch 10/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - accuracy: 0.8559 - loss: 0.3509
# Epoch 11/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - accuracy: 0.8550 - loss: 0.3503
# Epoch 12/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - accuracy: 0.8570 - loss: 0.3486
# Epoch 13/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.8551 - loss: 0.3488
# Epoch 14/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - accuracy: 0.8571 - loss: 0.3474
# Epoch 15/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - accuracy: 0.8561 - loss: 0.3468
# Epoch 16/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 0.8571 - loss: 0.3463
# Epoch 17/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - accuracy: 0.